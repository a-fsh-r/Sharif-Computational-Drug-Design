# %%
# %pip install rdkit
# %pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rdkit
#   Downloading rdkit-2022.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.3 MB)
#      |████████████████████████████████| 29.3 MB 1.6 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from rdkit) (1.21.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from rdkit) (7.1.2)
# Installing collected packages: rdkit
# Successfully installed rdkit-2022.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.9 MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (2.23.0)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 7.9 MB/s
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, itsdangerous, attrs, requests-cache, chembl-webresource-client
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# Successfully installed attrs-21.4.0 chembl-webresource-client-0.10.8 itsdangerous-2.1.2 requests-cache-0.7.5 url-normalize-1.4.3

# %%
from chembl_webresource_client.new_client import new_client
target = new_client.target
uniprot_id = 'P35916'
res = target.filter(target_components__accession=uniprot_id)

# %%
import pandas as pd
res = pd.DataFrame(res)
res
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'FLT4', 'xref_name': None, 'xref_...  Homo sapiens
# 1                                                 []  Homo sapiens
# 2                                                 []  Homo sapiens
# 3                                                 []  Homo sapiens
#
#                                            pref_name  species_group_flag  \
# 0      Vascular endothelial growth factor receptor 3               False
# 1        Vascular endothelial growth factor receptor               False
# 2  Vascular endothelial growth factor receptor 2 ...               False
# 3  Focal adhesion kinase 1/vascular endothelial g...               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL1955  [{'accession': 'P35916', 'component_descriptio...
# 1    CHEMBL2095227  [{'accession': 'P17948', 'component_descriptio...
# 2    CHEMBL2111409  [{'accession': 'P35916', 'component_descriptio...
# 3    CHEMBL3301389  [{'accession': 'P35916', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    9606
# 1               PROTEIN FAMILY    9606
# 2            SELECTIVITY GROUP    9606
# 3  PROTEIN-PROTEIN INTERACTION    9606

# %%
print ('\n'.join(target[0].keys()))
# Out:
# cross_references
# organism
# pref_name
# species_group_flag
# target_chembl_id
# target_components
# target_type
# tax_id

# %%
res['target_components'][0]
# Out:
# [{'accession': 'P35916',
#   'component_description': 'Vascular endothelial growth factor receptor 3',
#   'component_id': 279,
#   'component_type': 'PROTEIN',
#   'relationship': 'SINGLE PROTEIN',
#   'target_component_synonyms': [{'component_synonym': '2.7.10.1',
#     'syn_type': 'EC_NUMBER'},
#    {'component_synonym': 'FLT4', 'syn_type': 'GENE_SYMBOL'},
#    {'component_synonym': 'FLT-4', 'syn_type': 'UNIPROT'},
#    {'component_synonym': 'Fms-like tyrosine kinase 4', 'syn_type': 'UNIPROT'},
#    {'component_synonym': 'Tyrosine-protein kinase receptor FLT4',
#     'syn_type': 'UNIPROT'},
#    {'component_synonym': 'Vascular endothelial growth factor receptor 3',
#     'syn_type': 'UNIPROT'},
#    {'component_synonym': 'VEGFR3', 'syn_type': 'GENE_SYMBOL_OTHER'},
#    {'component_synonym': 'VEGFR-3', 'syn_type': 'UNIPROT'}],
#   'target_component_xrefs': [{'xref_id': 'FLT4',
#     'xref_name': 'Lymphedema, hereditary I (Milory disease)',
#     'xref_src_db': 'CGD'},
#    {'xref_id': 'P35916', 'xref_name': None, 'xref_src_db': 'ExpressionAtlas'},
#    {'xref_id': 'GO:0005576',
#     'xref_name': 'extracellular region',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0005634',
#     'xref_name': 'nucleus',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0005654',
#     'xref_name': 'nucleoplasm',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0005737',
#     'xref_name': 'cytoplasm',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0005829',
#     'xref_name': 'cytosol',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0005886',
#     'xref_name': 'plasma membrane',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0005887',
#     'xref_name': 'integral component of plasma membrane',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0016020',
#     'xref_name': 'membrane',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0016021',
#     'xref_name': 'integral component of membrane',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0043235',
#     'xref_name': 'receptor complex',
#     'xref_src_db': 'GoComponent'},
#    {'xref_id': 'GO:0000166',
#     'xref_name': 'nucleotide binding',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0004672',
#     'xref_name': 'protein kinase activity',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0004712',
#     'xref_name': 'protein serine/threonine/tyrosine kinase activity',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0004713',
#     'xref_name': 'protein tyrosine kinase activity',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0004714',
#     'xref_name': 'transmembrane receptor protein tyrosine kinase activity',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0005021',
#     'xref_name': 'vascular endothelial growth factor-activated receptor activity',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0005515',
#     'xref_name': 'protein binding',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0005524',
#     'xref_name': 'ATP binding',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0016301',
#     'xref_name': 'kinase activity',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0016740',
#     'xref_name': 'transferase activity',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0019838',
#     'xref_name': 'growth factor binding',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0019903',
#     'xref_name': 'protein phosphatase binding',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0042803',
#     'xref_name': 'protein homodimerization activity',
#     'xref_src_db': 'GoFunction'},
#    {'xref_id': 'GO:0001525',
#     'xref_name': 'angiogenesis',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0001934',
#     'xref_name': 'positive regulation of protein phosphorylation',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0001938',
#     'xref_name': 'positive regulation of endothelial cell proliferation',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0001944',
#     'xref_name': 'vasculature development',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0001945',
#     'xref_name': 'lymph vessel development',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0001946',
#     'xref_name': 'lymphangiogenesis',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0002040',
#     'xref_name': 'sprouting angiogenesis',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0002244',
#     'xref_name': 'hematopoietic progenitor cell differentiation',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0003016',
#     'xref_name': 'respiratory system process',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0006468',
#     'xref_name': 'protein phosphorylation',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0007169',
#     'xref_name': 'transmembrane receptor protein tyrosine kinase signaling pathway',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0007585',
#     'xref_name': 'respiratory gaseous exchange by respiratory system',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0008284',
#     'xref_name': 'positive regulation of cell population proliferation',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0010575',
#     'xref_name': 'positive regulation of vascular endothelial growth factor production',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0010595',
#     'xref_name': 'positive regulation of endothelial cell migration',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0016310',
#     'xref_name': 'phosphorylation',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0018108',
#     'xref_name': 'peptidyl-tyrosine phosphorylation',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0033674',
#     'xref_name': 'positive regulation of kinase activity',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0035924',
#     'xref_name': 'cellular response to vascular endothelial growth factor stimulus',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0038084',
#     'xref_name': 'vascular endothelial growth factor signaling pathway',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0043066',
#     'xref_name': 'negative regulation of apoptotic process',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0043410',
#     'xref_name': 'positive regulation of MAPK cascade',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0046330',
#     'xref_name': 'positive regulation of JNK cascade',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0046777',
#     'xref_name': 'protein autophosphorylation',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0048010',
#     'xref_name': 'vascular endothelial growth factor receptor signaling pathway',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0048286',
#     'xref_name': 'lung alveolus development',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0048514',
#     'xref_name': 'blood vessel morphogenesis',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0060312',
#     'xref_name': 'regulation of blood vessel remodeling',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0070374',
#     'xref_name': 'positive regulation of ERK1 and ERK2 cascade',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': 'GO:0090037',
#     'xref_name': 'positive regulation of protein kinase C signaling',
#     'xref_src_db': 'GoProcess'},
#    {'xref_id': '1814',
#     'xref_name': None,
#     'xref_src_db': 'GuideToPHARMACOLOGY'},
#    {'xref_id': 'P35916', 'xref_name': None, 'xref_src_db': 'IntAct'},
#    {'xref_id': 'IPR000719',
#     'xref_name': 'Prot_kinase_dom.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR001245',
#     'xref_name': 'Ser-Thr/Tyr_kinase_cat_dom.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR001824',
#     'xref_name': 'Tyr_kinase_rcpt_3_CS.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR003598',
#     'xref_name': 'Ig_sub2.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR003599', 'xref_name': 'Ig_sub.', 'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR007110',
#     'xref_name': 'Ig-like_dom.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR008266',
#     'xref_name': 'Tyr_kinase_AS.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR009137',
#     'xref_name': 'VEGFR3_rcpt.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR011009',
#     'xref_name': 'Kinase-like_dom_sf.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR013098',
#     'xref_name': 'Ig_I-set.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR013783',
#     'xref_name': 'Ig-like_fold.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR017441',
#     'xref_name': 'Protein_kinase_ATP_BS.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR020635',
#     'xref_name': 'Tyr_kinase_cat_dom.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR036179',
#     'xref_name': 'Ig-like_dom_sf.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': 'IPR041348',
#     'xref_name': 'VEGFR-2_TMD.',
#     'xref_src_db': 'InterPro'},
#    {'xref_id': '4BSJ', 'xref_name': 'A', 'xref_src_db': 'PDBe'},
#    {'xref_id': '4BSK', 'xref_name': 'A', 'xref_src_db': 'PDBe'},
#    {'xref_id': 'PF07679', 'xref_name': 'I-set', 'xref_src_db': 'Pfam'},
#    {'xref_id': 'PF07714',
#     'xref_name': 'PK_Tyr_Ser-Thr',
#     'xref_src_db': 'Pfam'},
#    {'xref_id': 'PF17988', 'xref_name': 'VEGFR-2_TMD', 'xref_src_db': 'Pfam'},
#    {'xref_id': 'PA28183',
#     'xref_name': 'fms-related tyrosine kinase 4',
#     'xref_src_db': 'PharmGKB'},
#    {'xref_id': 'P35916', 'xref_name': 'Tclin', 'xref_src_db': 'Pharos'},
#    {'xref_id': 'R-HSA-195399',
#     'xref_name': 'VEGF binds to VEGFR leading to receptor dimerization.',
#     'xref_src_db': 'Reactome'},
#    {'xref_id': 'R-HSA-9013695',
#     'xref_name': 'NOTCH4 Intracellular Domain Regulates Transcription.',
#     'xref_src_db': 'Reactome'},
#    {'xref_id': 'A8K6L4', 'xref_name': None, 'xref_src_db': 'UniProt'},
#    {'xref_id': 'B5A926', 'xref_name': None, 'xref_src_db': 'UniProt'},
#    {'xref_id': 'P35916', 'xref_name': None, 'xref_src_db': 'UniProt'},
#    {'xref_id': 'Q16067', 'xref_name': None, 'xref_src_db': 'UniProt'},
#    {'xref_id': 'Q86W07', 'xref_name': None, 'xref_src_db': 'UniProt'},
#    {'xref_id': 'Q86W08', 'xref_name': None, 'xref_src_db': 'UniProt'}]}]
